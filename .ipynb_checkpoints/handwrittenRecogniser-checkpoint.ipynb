# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# Out:
# WARNING:tensorflow:From C:\Users\Brian\miniconda3\envs\tf\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
mnist = tf.keras.datasets.mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
import random

# %%
fig, axes = plt.subplots(8,8, figsize=(5,5))
fig.tight_layout(pad=0.13,rect=[0, 0, 1, 1.1]) #[left, bottom, right, top]
for i,ax in enumerate(axes.flat):
    # Select random indices
    random_index = np.random.randint(len(x_train))
    
    # Display the image
    ax.imshow(x_train[random_index], cmap='gray')
    
    # Display the label above the image
    ax.set_title(y_train[random_index], fontsize=12)
    ax.set_axis_off()

# %%
x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28,28)))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(10, activation='softmax'))
# Out:
# WARNING:tensorflow:From C:\Users\Brian\miniconda3\envs\tf\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\Brian\miniconda3\envs\tf\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# WARNING:tensorflow:From C:\Users\Brian\miniconda3\envs\tf\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Brian\miniconda3\envs\tf\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2630 - accuracy: 0.9211
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1100 - accuracy: 0.9657
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0757 - accuracy: 0.9760
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0547 - accuracy: 0.9826
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0421 - accuracy: 0.9863

# %%
loss, accuracy = model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1053 - accuracy: 0.9691

# %%
loss, accuracy
# Out:
# (0.10530585795640945, 0.9690999984741211)

# %%
def plot_loss_tf(history):
    fig,ax = plt.subplots(1,1, figsize = (4,3))
    fig.canvas.toolbar_visible = False
    fig.canvas.header_visible = False
    fig.canvas.footer_visible = False
    ax.plot(history.history['loss'], label='loss')
    ax.set_ylim([0, 0.3])
    ax.set_xlabel('Epoch')
    ax.set_ylabel('loss (cost)')
    ax.legend()
    ax.grid(True)
    plt.show()

# %%
plot_loss_tf(history)

# %%
model.save('handwritten.model')
# Out:
# INFO:tensorflow:Assets written to: handwritten.model\assets

# %%
model = tf.keras.models.load_model('handwritten.modelv1')
# Out:
# WARNING:tensorflow:From C:\Users\Brian\miniconda3\envs\tf\lib\site-packages\keras\src\saving\legacy\saved_model\load.py:107: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# WARNING:tensorflow:From C:\Users\Brian\miniconda3\envs\tf\lib\site-packages\keras\src\utils\tf_utils.py:585: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
image_number = 1
while os.path.isfile(f"digits/digit{image_number}.png"):
    try:
        img = cv2.imread(f"digits/digit{image_number}.png")[:,:,0]
        img = np.invert(np.array([img]))
        prediction = model.predict(img)
        print(f"This digit is probably a {np.argmax(prediction)}")
        plt.imshow(img[0], cmap=plt.cm.binary)
        plt.show()
    except:
        print("Error")
    finally:
        image_number += 1
# Out:
# 1/1 [==============================] - 0s 79ms/step
# This digit is probably a 5
# 1/1 [==============================] - 0s 19ms/step
# This digit is probably a 2
# 1/1 [==============================] - 0s 18ms/step
# This digit is probably a 2
# 1/1 [==============================] - 0s 18ms/step
# This digit is probably a 6
# 1/1 [==============================] - 0s 18ms/step
# This digit is probably a 3
# 1/1 [==============================] - 0s 18ms/step
# This digit is probably a 9
# 1/1 [==============================] - 0s 18ms/step
# This digit is probably a 1
# 1/1 [==============================] - 0s 18ms/step
# This digit is probably a 4
# 1/1 [==============================] - 0s 20ms/step
# This digit is probably a 3
# 1/1 [==============================] - 0s 18ms/step
# This digit is probably a 1
# 1/1 [==============================] - 0s 19ms/step
# This digit is probably a 7
# 1/1 [==============================] - 0s 19ms/step
# This digit is probably a 3
# 1/1 [==============================] - 0s 19ms/step
# This digit is probably a 0
# 1/1 [==============================] - 0s 18ms/step
# This digit is probably a 8
